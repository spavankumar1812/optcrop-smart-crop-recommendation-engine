# %% [markdown]
# # OptiCrop Training Notebook
# This notebook demonstrates generating the synthetic dataset and training the models using the `train.py` script.

# %%
# Run the training script to create dataset and train models
# !python ../train.py
# Out:
# Traceback (most recent call last):
#   File "C:\c\Users\S PAVAN KUMAR\Desktop\OptiCrop\train.py", line 3, in <module>
#     from sklearn.model_selection import train_test_split
# ModuleNotFoundError: No module named 'sklearn'
